# %% [markdown]
# # Преамбула
# Экзамен состоит из трёх блоков:
# - программирование на python;
# - работа с датафреймами и описательная статистика;
# - классическое машинное обучение.
#
# В каждом вопросе может быть **любое** количество правильных ответов.
# Стоимость вопроса равна одному баллу, если не сказано иное.
# Для успешной сдачи экзамена необходимо набрать 50% и более от максимального числа баллов.
#
# - **NB:** В первом блоке (программирование на python) **ЗАПРЕЩЕНО** пользоваться библиотеками, не посталяемыми вместе с python по-умолчанию (т.е. pandas/numpy нельзя использовать в это блоке, а random/json -- можно);
# - Все спорные моменты трактуются в пользу экзаменуемого;
# - Ваш код должен быть воспроизводим (если я положу исходные файлы в ту же папку, что и Ваш ноутбук, и нажму `Run` -> `Run All Cells`, то всё должно работать). Так что соблюдайте логику и последовательнось запуска ячеек. Спасибо :)
# - Можно пользоваться только своей головой, но любыми материалами и интернетом;
# - Если задание кажется сложным -- пропустите его;
#
# - Во время экзамена я буду отвечать только на вопросы касаемо формулировок заданий.
#
# Главное, не спешите, проверяйте, что и куда записывается.
# За каждого болею.
# Всем удачи!

# %% [markdown]
# # Программирование на python

# %% [markdown]
# ### 1.
# Какие из нижеперечисленных операций вызовут ошибки при запуске?
# a) `list(123)`
# b)  `list('123')`
# c)  `list(['123'])`
# d)  `list(list('123'))`

# %% [markdown]
# ### 2.1

# %% [markdown]
# <center><img src='https://upload.wikimedia.org/wikipedia/ru/thumb/7/78/Trollface.svg/1200px-Trollface.svg.png' width=50%/></center>
# <center>Изображение интернет-тролля (<a href='https://ru.wikipedia.org/wiki/Trollface'>wiki</a>)</center>
# <br>
# Любрая растровая картинка состоит из <a href='https://ru.wikipedia.org/wiki/%D0%9F%D0%B8%D0%BA%D1%81%D0%B5%D0%BB%D1%8C'>пикселей</a>, каждый из которых кодирует цвет.
# Картинка выше черно-белая, а значит каждому пикселю достаточно принимать всего 2 значения, чтобы закодировать цвет: 0 -- чёрный цвет, 1 -- белый цвет.
# Иными словами, каждый пиксель "весит" 1 бит.
# <br>
# Задание:
# Будем считать, что размер изображения выше 1200x1200 пикселей (1200 на 1200). Считая, что каждый пиксель весит 1 бит, найдите сколько это изображение "весит" в байтах (1 байт состоит из 8 бит).

# %% [markdown]
# ### 2.2
# Сконвертируйте ответ предыдущей задачи в килобайты (считаем, что кило -- 10^3).
# *ответ округлите до меньшего целого числа

# %% [markdown]
# ### 2.3
#
# <center><img src='https://cdn.wallpapersafari.com/34/84/nx4Qhb.jpg' width=50%/></center>
# <center>Изображение интернет-тролля с цветным фоном(<a href='https://ru.wikipedia.org/wiki/Trollface'>wiki</a>)</center>
# <br>
# Изображение выше теперь не чёрно-белое, а цветное. Каждый пиксель кодирует три цвета: красный, зелёный, синий. Т.е. кодируется три числа. Каждое число принимает значения от 0 до 255, т.е. всего 256 возможных значений. 256 значений можно закодировать одним байтом (1 байт -- 8 бит. 8 позиций с 0 или 1. Число возможных последовательностей длины 8 из нулей и единиц равно 2^8=256).
# Конечный цвет пикселя -- комбинация из красного, зелёного, синего (RGB).
# Таким образом, каждый пиксель "весит" не 1 бит, как в предыдущей картинке, а 3 байта.
# <br>
# Задание:
# Будем считать, что размер изображения выше 900x900 пикселей (900 на 900). Считая, что каждый пиксель весит 3 байта, найдите сколько это изображение "весит" в килобайтах (1 байт состоит из 8 бит, кило -- 10^3).

# %% [markdown]
# ### 3.
# Сумма платежа по кредиту с аннуитетный способом погашения вычисляется по следующей формуле:
# <center><img src='https://credistory.ru/blog/images/raschet-annuitetnogo-platezha.jpg'/></center>

# %% [markdown]
# Напишите программу, которая принимает сумму кредиты, процентную ставку (r%), количество месяцев, на которое берется кредит, и выводит сумму ежемесячного платежа.
#
# Ввод:
# Три числа на трёх строках:
# - сумма кредита (целое число у.е.);
# - месячная процентная ставка (в процентах, а не долях единицы. Т.е. для кредита под 24% годовых для r будет введено 2, а не 0.02);
# - n (целое число месяцев).
#
# Вывод:
# Платёж по кредиту округлённый до ближайшего целого числа **вниз**.

# %% [markdown]
# ### 4.
# Соберите Ваше решение предыдущей задачи в функцию, которая принимает **S**, **r**, **n** в качестве аргументов.
#
# - Используйте говорящее название для функции;
# - используйте осмысленные названия локальных переменных функции;
# - функция должна **возвращать** значение платежа, а не печатать его.

# %% [markdown]
# ### 5.
# Напишите функцию, которая принимает сумму кредита, процентную ставку, целое число месяцев, на которое берётся кредит, и печатает (выводит на экран) информационное сообщение следующего типа:
# ```
# Сумма кредита: S
# Сумма выплат: XXX
# Переплата:  YYY
# Переплата (%): ZZZ
# ```
#
# Т.е. внутри функции надо определить сумму выплат, сумму переплаты и значение переплаты в % от исходной суммы кредита.
#
# Указание:
# Функция должна использовать функцию из задания 4.

# %% [markdown]
# ### 6.
# Дан файл `clients.csv` с информацией о заёмщиках:
# - имя
# - размер кредита
# - процентная ставка (годовая)
# - срок кредита (число месяцев)
#
# Создайте файл `profit.csv` с двумя колонками:
# - имя клиента;
# - переплата по кредиту (разница суммы выплат и исходного кредита)
#
# Для решения пользуйтесь функциями из задач 4 и 5.

# %% [markdown]
# ### 7. (3 балла)
#
# Создайте конструктор класса Loaner, экземпляры класса которого при создании принимают:
# - имя заёмщника;
# - размер кредита;
# - процентная ставка (месячная);
# - продолжительность кредитования (в месяцах).
#
# Принимаемые значение должны сохраняться в атрибуты.
#
# Реализуйте методы:
# 1. `calculate_payment` (определяет и возвращает сумму аннуитетного платежа по кредиту, округлённую до ближайшего целого числа вниз);
# 2. `calculate_payments_total` (определяет и возвращает сумму выплат по кредиту);
# 3. `calculate_overpayment` (определяет и возвращает сумму переплат);
# 4. `__repr__` (строкове представление экземпляра класса в произвольном формате)

# %% [markdown]
# ### 8.
# Модифициуйте класс из предыдущей задачи таким образом, чтобы метода "`calculate_...`" не считали значения каждый раз, а как-то сохраняли его. И чтобы при повторном вызове метода возвращалось ранее посчитанное значение, а не считалось заново.

# %% [markdown]
# # Работа с табличными данными
#
# Дан файл `credit_scoring_data.csv` с информацией о заёмщиках, для которых был проведён кредитный скоринг.
# Разделитель -- знак табуляции.

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_csv('exam_credit_scoring_data.csv', encoding='utf8', sep='\t', index_col=0)
df.head()
# Out:
#        ID Customer_ID     Month           Name  Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh   23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh   23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh   23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh   23  821-00-0265  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                  3  ...           _
# 1       19114.12                    NaN                  3  ...        Good
# 2       19114.12                    NaN                  3  ...        Good
# 3       19114.12                    NaN                  3  ...        Good
# 4       19114.12            1824.843333                  3  ...        Good
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85852 entries, 0 to 99998
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        85852 non-null  object
#  1   Customer_ID               85852 non-null  object
#  2   Month                     85852 non-null  object
#  3   Name                      77267 non-null  object
#  4   Age                       85852 non-null  int64
#  5   SSN                       85852 non-null  object
#  6   Occupation                85852 non-null  object
#  7   Annual_Income             85852 non-null  float64
#  8   Monthly_Inhand_Salary     72993 non-null  float64
#  9   Num_Bank_Accounts         85852 non-null  int64
#  10  Num_Credit_Card           85852 non-null  int64
#  11  Interest_Rate             85852 non-null  int64
#  12  Num_of_Loan               85852 non-null  object
# ...

# %% [markdown]
# ### 9.
# Определите число пропусков для каждой колонки.
#
# Ожидаемый результат:
# <kbd>
# ![изображение.png](attachment:b7f81be4-dce4-4eec-afa3-d59cca07c144.png)
# </kbd>

# %% [markdown]
# ### 10.
# Удалите все стркои из датафрейма, содержащие хотя бы 1 пропуск, и перезапишите результат в переменную _df_.

# %% [markdown]
# ### 11.
# Сконвертируйте все колонки из списка ниже в тип данных `float` (и замените их в датафрейме на эти float-колонки).
#
# ps: так как я предварительно убрал из данных мусор, то колонки ниже у Вас и так прочитались как целые числа или float. Но такое будет не всегда. Так что задание имеет смысл :)

# %% [markdown]
# ### 12.
# Определите среднюю годовую зарплату (Annual_Income) для каждой профессии (Occupation).
# Результаты округлите до 1 знака после запятой.
#
# Ожидаемый результат:
# <kbd>
# ![изображение.png](attachment:2aadae0e-ec58-4f45-978e-b2f6c59d93f5.png)
# </kbd>

# %% [markdown]
# ### 13.
# Постройте вертикальный barplot для числа строк каждой профессии (Occupation).
# *(определите параметр, отвечающий за ориентацию графика)
#
# Ожидаемый результат:
# <kbd>
# ![изображение.png](attachment:b81cfc67-2d73-44be-ab48-7f9cb937ff03.png)
# </kbd>
#
# _ps: Вообще, смысла раскрашивать такие графики нет, так как цвет нам тут ничего не даёт. Так что в жизни я бы советовал окрашивать все столбцы одинаково, если цвет ничего не сообщает._

# %% [markdown]
# ### 14.
# Для каждой профессии (Occupation) определите для столбца Annual_income:
# 1. Квантиль уровня 0.1;
# 2. Медиану;
# 3. Квантиль уровня 0.9.
#
# Результаты объедините в один датафрейм и отсортируйте по медиану в порядке убывания.
#
# Ожидаемый результат:
# <kbd>
# ![изображение.png](attachment:a7365814-d6d8-4232-9cd6-5d4ebbd6aedf.png)
# </kbd>

# %% [markdown]
# ### 14.2
# Решите предыдущую задачу (14) с помощью одной строки кода.
# *Имею в виду, что можно делать переносы строк для красоты, но это должна быть одна длинная команда.

# %% [markdown]
# ### 15. (2.5 балла)
# Для каждого Credit_Score определите топ-3 профессии по значению Amount_invested_monthly.

# %% [markdown]
# # Введение в классическое машинное обучение
#
# Будем работать с тем же файлом exam_credit_scoring_data.csv
#
# NB: задания этого блока **не получится выполнить, не сделав пункты 10 и 11 из предыдущего блока**, так как нужно удалить строки с пропусками и сконвертировать числовые столбцы в числа, если они вдруг не сконвертировались.

# %% [markdown]
# ### 16 (4 балла)
# Только на числовых признаках обучите модель многоклассовой логистической регрессии с параметрами по-умолчанию для определения кредитного скора клиента.
#
# Указания:
# 1. Закодируйте целевую переменную (Credit_Score) с помощью label encdoing;
# 2. Разбейте данные для трейн и тест (размер тестовой выборки 25%, сид для рандомизации: 19032023 );
# 3. Обучите модель на тренинговой выборке;
# 4. Сделайте предсказания модель на тестовой выборке;
# 5. Посчитайте f1-score для предсказаний;

# %% [markdown]
# ### 17 (3 балла)
# На том же разбиении на трейн и тест (на тех же данных) обучите модель многоклассовой логистической регрессии с параметрами по-умолчанию на стандартизованных данных.
#
# Указания:
# 1. Используйте трейн и тест, полученные в предыдущей задаче;
# 2. Стандартизуйте данные с помощью MinMaxScaler (не забудьте, на ком делать фит, на ком трансформ);
# 3. Обучите модель лог.регрессии на тренинговых данных;
# 4. Получите предсказания для тестовой выборки;
# 5. Посчитайте значение f1-score;
# 6. Получилось за значение лучше или хуже, чем в задаче 16? Почему такое могло случиться? Что могло повилять и как?

# %% [markdown]
# ### 18. (5 баллов)
# На исходных данных (не стандартизованных) обучите модель случайного леса (RandomForestClassifier) и определите оптимальные параметры с помощью GridSearchCV.
#
# Укаазния:
# 1. Разбейте данные на трейн и тест (размер тестовой выборки 25%, сид для рандомизации: 19032023 );
# 2. Создайте сетку параметров для GridSearchCV.
#    Значения для перебора:
#    - `n_estimators: 10, 25, 50, 100`
#    - `max_depth: 3, 5, 10, None`
#    - `max_features: "sqrt", "log2", None`
#
# Для скоринга используйте f1-score.
# (GridSearchCV учите только на тренинговой выборке)
#
# 3. На лучшей модели из GridSearchCV (атрибут best_estimator_ или как-то так) сделайте предсказания для тестовой выборки;
# 4. Определите roc_auc_score для предсказания.

# %% [markdown]
# ![изображение.png](attachment:991e41f4-2777-4644-b36a-6b9535f6f07c.png)
