# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from glob import glob
help(glob)
# Out:
# Help on function glob in module glob:
#
# glob(pathname, *, recursive=False)
#     Return a list of paths matching a pathname pattern.
#
#     The pattern may contain simple shell-style wildcards a la
#     fnmatch. However, unlike fnmatch, filenames starting with a
#     dot are special cases that are not matched by '*' and '?'
#     patterns.
#
#     If recursive is true, the pattern '**' will match any files and
#     zero or more directories and subdirectories.

# %% [markdown]
# # merge, concat, join

# %%
files = glob("data/*tsv") # получим список с файлами
files
# Out:
# ['data\\10_16-05_20-57_.tsv',
#  'data\\20_17-05_20-00_.tsv',
#  'data\\30_18-05_08-11_.tsv',
#  'data\\40_19-05_04-00_.tsv']

# %%
df1 = pd.read_csv('data\\10_16-05_20-57_.tsv', sep='\t') # , index_col=0
df1.head(3)
# Out:
#           id  Всего сообщений  Сообщений ученика  Сообщений учителя
# 0  162881860               14                  9                  5
# 1  163720554               19                 10                  9
# 2  542225346                8                  2                  6

# %%
df2 = pd.read_csv('data\\20_17-05_20-00_.tsv', sep='\t')
df2.head(3)
# Out:
#           id  Всего сообщений  Сообщений ученика  Сообщений учителя
# 0  304741397               14                  6                  8
# 1  222306609               30                 16                 14
# 2  406929921                9                  5                  4

# %% [markdown]
# ## merge

# %% [markdown]
# ![joins](https://www.dofactory.com/img/sql/sql-joins.png)

# %%
print(df1.shape)
print(df2.shape)
# Out:
# (4555, 4)
# (4909, 4)

# %%
len(set(df1.id.unique()) & set(df2.id.unique()))
# Out:
# 4534

# %%
np.intersect1d(df1.id.unique(), df2.id.unique()).size
# Out:
# 4534

# %%
pd.merge(df1, df2) # пересечение по всем колонкам
# Out:
#             id  Всего сообщений  Сообщений ученика  Сообщений учителя
# 0    420405185               11                  6                  5
# 1    347431252               10                  3                  7
# 2    409439496                4                  2                  2
# 3    336133315               28                 11                 17
# 4    158278400                9                  5                  4
# ..         ...              ...                ...                ...
# 427   53318580                5                  3                  2
# 428   52048252                9                  5                  4
# 429   44351820                7                  4                  3
# 430   32888911                1                  1                  0
# 431   29237466                8                  4                  4
#
# [432 rows x 4 columns]

# %%
df1['id'].unique().size
# Out:
# 4539

# %%
# как надо:
m = pd.merge(left=df1, right=df2, on='id')
m = m.drop_duplicates()
m
# Out:
#              id  Всего сообщений_x  Сообщений ученика_x  Сообщений учителя_x  \
# 0     162881860                 14                    9                    5
# 1     163720554                 19                   10                    9
# 2     542225346                  8                    2                    6
# 3     433941477                 15                    8                    7
# 4     178097868                 56                   33                   23
# ...         ...                ...                  ...                  ...
# 4555   52048252                  9                    5                    4
# 4556   44351820                  7                    4                    3
# 4557   32888911                  1                    1                    0
# 4558   29237466                  8                    4                    4
# 4559    6629705                  3                    2                    1
#
#       Всего сообщений_y  Сообщений ученика_y  Сообщений учителя_y
# 0                    15                   10                    5
# 1                    38                   20                   18
# 2                    12                    5                    7
# 3                    41                   22                   19
# 4                    77                   46                   31
# ...                 ...                  ...                  ...
# 4555                  9                    5                    4
# 4556                  7                    4                    3
# 4557                  1                    1                    0
# 4558                  8                    4                    4
# 4559                  4                    3                    1
#
# [4534 rows x 7 columns]

# %%
m.id.nunique()
# Out:
# 4534

# %%
m[m.duplicated(keep=False)]
# Out:
#              id  Всего сообщений_x  Сообщений ученика_x  Сообщений учителя_x  \
# 14    407179642                 13                    5                    8
# 15    407179642                 13                    5                    8
# 197   508420727                 11                    6                    5
# 198   508420727                 11                    6                    5
# 199   418053276                  5                    2                    3
# 200   418053276                  5                    2                    3
# 201   238410574                  3                    1                    2
# 202   238410574                  3                    1                    2
# 455   400633906                  6                    5                    1
# 456   400633906                  6                    5                    1
# 597   515547655                  1                    1                    0
# 598   515547655                  1                    1                    0
# 599   515271593                  4                    4                    0
# 600   515271593                  4                    4                    0
# 601   514754269                  3                    3                    0
# 602   514754269                  3                    3                    0
# 999   409108133                  4                    4                    0
# 1000  409108133                  4                    4                    0
# 1207  361756202                  3                    3                    0
# 1208  361756202                  3                    3                    0
# 1209  361691792                  4                    4                    0
# 1210  361691792                  4                    4                    0
# 1401  322437362                 18                   10                    8
# 1402  322437362                 18                   10                    8
# 1799  263156193                  4                    4                    0
# 1800  263156193                  4                    4                    0
# 1801  262956487                  1                    1                    0
# 1802  262956487                  1                    1                    0
# 1803  262836421                  4                    4                    0
# 1804  262836421                  4                    4                    0
# 2000  240645798                  4                    4                    0
# 2001  240645798                  4                    4                    0
# 2399  209767777                  7                    5                    2
# 2400  209767777                  7                    5                    2
# 2401  209726724                  4                    4                    0
# 2402  209726724                  4                    4                    0
# 2600  194933041                  3                    3                    0
# 2601  194933041                  3                    3                    0
# 2657  190665649                  7                    5                    2
# 2658  190665649                  7                    5                    2
# 2659  190653488                  7                    3                    4
# 2660  190653488                  7                    3                    4
# 2835  179354568                  4                    4                    0
# 2836  179354568                  4                    4                    0
# 3203  159511817                  4                    4                    0
# 3204  159511817                  4                    4                    0
# 3571  139048474                  9                    6                    3
# 3572  139048474                  9                    6                    3
# 4097   33597415                  4                    4                    0
# 4098   33597415                  4                    4                    0
# 4099   33412452                  4                    4                    0
# 4100   33412452                  4                    4                    0
#
#       Всего сообщений_y  Сообщений ученика_y  Сообщений учителя_y
# 14                   23                    9                   14
# 15                   23                    9                   14
# 197                  12                    7                    5
# 198                  12                    7                    5
# 199                   6                    3                    3
# 200                   6                    3                    3
# 201                   3                    1                    2
# 202                   3                    1                    2
# 455                   7                    6                    1
# 456                   7                    6                    1
# 597                   2                    2                    0
# 598                   2                    2                    0
# 599                   5                    5                    0
# 600                   5                    5                    0
# 601                   4                    4                    0
# 602                   4                    4                    0
# 999                   5                    5                    0
# 1000                  5                    5                    0
# 1207                  4                    4                    0
# 1208                  4                    4                    0
# 1209                  5                    5                    0
# 1210                  5                    5                    0
# 1401                 22                   12                   10
# 1402                 22                   12                   10
# 1799                  5                    5                    0
# 1800                  5                    5                    0
# 1801                  2                    2                    0
# 1802                  2                    2                    0
# 1803                  5                    5                    0
# 1804                  5                    5                    0
# 2000                  5                    5                    0
# 2001                  5                    5                    0
# 2399                  8                    6                    2
# 2400                  8                    6                    2
# 2401                  7                    6                    1
# 2402                  7                    6                    1
# 2600                  4                    4                    0
# 2601                  4                    4                    0
# 2657                  8                    6                    2
# 2658                  8                    6                    2
# 2659                  8                    4                    4
# 2660                  8                    4                    4
# 2835                  5                    5                    0
# 2836                  5                    5                    0
# 3203                  5                    5                    0
# 3204                  5                    5                    0
# 3571                 10                    7                    3
# 3572                 10                    7                    3
# 4097                  5                    5                    0
# 4098                  5                    5                    0
# 4099                  5                    5                    0
# 4100                  5                    5                    0

# %%
m.drop_duplicates().shape
# Out:
# (4534, 7)

# %%
pd.merge(left=df1, right=df2, on='id', suffixes=["_1", "_2"])
# Out:
#              id  Всего сообщений_1  Сообщений ученика_1  Сообщений учителя_1  \
# 0     162881860                 14                    9                    5
# 1     163720554                 19                   10                    9
# 2     542225346                  8                    2                    6
# 3     433941477                 15                    8                    7
# 4     178097868                 56                   33                   23
# ...         ...                ...                  ...                  ...
# 4555   52048252                  9                    5                    4
# 4556   44351820                  7                    4                    3
# 4557   32888911                  1                    1                    0
# 4558   29237466                  8                    4                    4
# 4559    6629705                  3                    2                    1
#
#       Всего сообщений_2  Сообщений ученика_2  Сообщений учителя_2
# 0                    15                   10                    5
# 1                    38                   20                   18
# 2                    12                    5                    7
# 3                    41                   22                   19
# 4                    77                   46                   31
# ...                 ...                  ...                  ...
# 4555                  9                    5                    4
# 4556                  7                    4                    3
# 4557                  1                    1                    0
# 4558                  8                    4                    4
# 4559                  4                    3                    1
#
# [4560 rows x 7 columns]

# %%
pd.merge(left=df1, right=df2, on='id', suffixes=[' | файл1', ' | файл2']).head()
# Out:
#           id  Всего сообщений | файл1  Сообщений ученика | файл1  \
# 0  162881860                       14                          9
# 1  163720554                       19                         10
# 2  542225346                        8                          2
# 3  433941477                       15                          8
# 4  178097868                       56                         33
#
#    Сообщений учителя | файл1  Всего сообщений | файл2  \
# 0                          5                       15
# 1                          9                       38
# 2                          6                       12
# 3                          7                       41
# 4                         23                       77
#
#    Сообщений ученика | файл2  Сообщений учителя | файл2
# 0                         10                          5
# 1                         20                         18
# 2                          5                          7
# 3                         22                         19
# 4                         46                         31

# %%
# validate
# 1:1
# m:1
# 1:m

pd.merge(left=df1, right=df2, on='id', suffixes=[' | файл1', 'файл2'], validate="one_to_one") # потому что есть дубли в обоих датафреймах
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In [27], line 6
#       1 # validate
#       2 # 1:1
#       3 # m:1
#       4 # 1:m
# ----> 6 pd.merge(left=df1, right=df2, on='id', suffixes=[' | файл1', 'файл2'], validate="one_to_one") # потому что есть дубли в обоих датафреймах
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
#     121         indicator=indicator,
#     122         validate=validate,
#     123     )
#     124     return op.get_result(copy=copy)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\merge.py:713, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     709 # If argument passed to validate,
#     710 # check if columns specified as unique
#     711 # are in fact unique.
#     712 if validate is not None:
# --> 713     self._validate(validate)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\merge.py:1510, in _MergeOperation._validate(self, validate)
#    1508 if validate in ["one_to_one", "1:1"]:
#    1509     if not left_unique and not right_unique:
# -> 1510         raise MergeError(
#    1511             "Merge keys are not unique in either left "
#    1512             "or right dataset; not a one-to-one merge"
#    1513         )
#    1514     elif not left_unique:
#    1515         raise MergeError(
#    1516             "Merge keys are not unique in left dataset; not a one-to-one merge"
#    1517         )
#
# MergeError: Merge keys are not unique in either left or right dataset; not a one-to-one merge

# %%
Товар,Арт
1,1111
2,2222

Кодификатор
Арт,Описание
1111,'А'
1111,'Б'
1111,'В'

Товар,Арт,Описание
1,1111,'A'
1,1111,'Б'
1,1111,'В'

# %%
pd.merge(
    left=df1.drop_duplicates(), 
    right=df2.drop_duplicates(), 
    on='id', 
    suffixes=[' | файл1', 'файл2'], 
    validate="1:1")
# Out:
#              id  Всего сообщений | файл1  Сообщений ученика | файл1  \
# 0     162881860                       14                          9
# 1     163720554                       19                         10
# 2     542225346                        8                          2
# 3     433941477                       15                          8
# 4     178097868                       56                         33
# ...         ...                      ...                        ...
# 4529   52048252                        9                          5
# 4530   44351820                        7                          4
# 4531   32888911                        1                          1
# 4532   29237466                        8                          4
# 4533    6629705                        3                          2
#
#       Сообщений учителя | файл1  Всего сообщенийфайл2  Сообщений ученикафайл2  \
# 0                             5                    15                      10
# 1                             9                    38                      20
# 2                             6                    12                       5
# 3                             7                    41                      22
# 4                            23                    77                      46
# ...                         ...                   ...                     ...
# 4529                          4                     9                       5
# 4530                          3                     7                       4
# 4531                          0                     1                       1
# 4532                          4                     8                       4
# 4533                          1                     4                       3
#
#       Сообщений учителяфайл2
# 0                          5
# 1                         18
# 2                          7
# 3                         19
# 4                         31
# ...                      ...
# 4529                       4
# 4530                       3
# 4531                       0
# 4532                       4
# 4533                       1
#
# [4534 rows x 7 columns]

# %%
pd.merge(left=df1, right=df2, on='id', suffixes=[' | файл1', 'файл2'], validate="many_to_many").head() # проходит проверку
# Out:
#           id  Всего сообщений | файл1  Сообщений ученика | файл1  \
# 0  162881860                       14                          9
# 1  163720554                       19                         10
# 2  542225346                        8                          2
# 3  433941477                       15                          8
# 4  178097868                       56                         33
#
#    Сообщений учителя | файл1  Всего сообщенийфайл2  Сообщений ученикафайл2  \
# 0                          5                    15                      10
# 1                          9                    38                      20
# 2                          6                    12                       5
# 3                          7                    41                      22
# 4                         23                    77                      46
#
#    Сообщений учителяфайл2
# 0                       5
# 1                      18
# 2                       7
# 3                      19
# 4                      31

# %%
m = pd.merge(left=df1, right=df2, how='left', on='id', 
         suffixes=[' | файл1', 'файл2'], 
         validate="many_to_many") # проходит проверку

m[m['Сообщений учителяфайл2'].isna()]
# Out:
#              id  Всего сообщений | файл1  Сообщений ученика | файл1  \
# 117    97484555                        5                          4
# 303   138706633                        4                          2
# 1944  248434643                        6                          5
# 3497  143188892                        3                          3
# 3589  138585345                        4                          4
#
#       Сообщений учителя | файл1  Всего сообщенийфайл2  Сообщений ученикафайл2  \
# 117                           1                   NaN                     NaN
# 303                           2                   NaN                     NaN
# 1944                          1                   NaN                     NaN
# 3497                          0                   NaN                     NaN
# 3589                          0                   NaN                     NaN
#
#       Сообщений учителяфайл2
# 117                      NaN
# 303                      NaN
# 1944                     NaN
# 3497                     NaN
# 3589                     NaN

# %%
df1_no_dupl = df1.drop_duplicates()
df1_no_dupl.shape
# Out:
# (4539, 4)

# %%
df2_no_dupl = df2.drop_duplicates()
df2_no_dupl.shape
# Out:
# (4896, 4)

# %%
pd.merge(df1_no_dupl, df2_no_dupl, on='id', validate='one_to_one')
# Out:
#              id  Всего сообщений_x  Сообщений ученика_x  Сообщений учителя_x  \
# 0     162881860                 14                    9                    5
# 1     163720554                 19                   10                    9
# 2     542225346                  8                    2                    6
# 3     433941477                 15                    8                    7
# 4     178097868                 56                   33                   23
# ...         ...                ...                  ...                  ...
# 4529   52048252                  9                    5                    4
# 4530   44351820                  7                    4                    3
# 4531   32888911                  1                    1                    0
# 4532   29237466                  8                    4                    4
# 4533    6629705                  3                    2                    1
#
#       Всего сообщений_y  Сообщений ученика_y  Сообщений учителя_y
# 0                    15                   10                    5
# 1                    38                   20                   18
# 2                    12                    5                    7
# 3                    41                   22                   19
# 4                    77                   46                   31
# ...                 ...                  ...                  ...
# 4529                  9                    5                    4
# 4530                  7                    4                    3
# 4531                  1                    1                    0
# 4532                  8                    4                    4
# 4533                  4                    3                    1
#
# [4534 rows x 7 columns]

# %% [markdown]
# ## join

# %%
# получится фигня, потому что join соединяет по индексам правого датафрейма (для левого можно указать столбец)
df1.join(df2, lsuffix='_left', rsuffix='_right')  # важно указать суффиксы
# Out:
#         id_left  Всего сообщений_left  Сообщений ученика_left  \
# 0     162881860                    14                       9
# 1     163720554                    19                      10
# 2     542225346                     8                       2
# 3     433941477                    15                       8
# 4     178097868                    56                      33
# ...         ...                   ...                     ...
# 4550   52048252                     9                       5
# 4551   44351820                     7                       4
# 4552   32888911                     1                       1
# 4553   29237466                     8                       4
# 4554    6629705                     3                       2
#
#       Сообщений учителя_left   id_right  Всего сообщений_right  \
# 0                          5  304741397                     14
# 1                          9  222306609                     30
# 2                          6  406929921                      9
# 3                          7  439552406                     34
# 4                         23  173017583                     10
# ...                      ...        ...                    ...
# 4550                       4  439550436                      6
# 4551                       3  269693861                      7
# 4552                       0  266473129                     11
# 4553                       4  124968658                      6
# 4554                       1  135950991                      5
#
#       Сообщений ученика_right  Сообщений учителя_right
# 0                           6                        8
# 1                          16                       14
# 2                           5                        4
# 3                          16                       18
# 4                           9                        1
# ...                       ...                      ...
# 4550                        3                        3
# 4551                        3                        4
# 4552                        4                        7
# 4553                        3                        3
# 4554                        3                        2
#
# [4555 rows x 8 columns]

# %%
df1.join(df2, on='id', lsuffix='_left', rsuffix='_right').head() # все еще не работает
# Out:
#      id_left  Всего сообщений_left  Сообщений ученика_left  \
# 0  162881860                    14                       9
# 1  163720554                    19                      10
# 2  542225346                     8                       2
# 3  433941477                    15                       8
# 4  178097868                    56                      33
#
#    Сообщений учителя_left  id_right  Всего сообщений_right  \
# 0                       5       NaN                    NaN
# 1                       9       NaN                    NaN
# 2                       6       NaN                    NaN
# 3                       7       NaN                    NaN
# 4                      23       NaN                    NaN
#
#    Сообщений ученика_right  Сообщений учителя_right
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN

# %%
df2_indexed = df2.set_index('id') # сохраним индекс 
df2_indexed.head()
# Out:
#            Всего сообщений  Сообщений ученика  Сообщений учителя
# id
# 304741397               14                  6                  8
# 222306609               30                 16                 14
# 406929921                9                  5                  4
# 439552406               34                 16                 18
# 173017583               10                  9                  1

# %%
# если хотим вернуть как было
df2_indexed.reset_index(drop=True) # операция не in place, надо сохранять результат!
# Out:
#       Всего сообщений  Сообщений ученика  Сообщений учителя
# 0                  14                  6                  8
# 1                  30                 16                 14
# 2                   9                  5                  4
# 3                  34                 16                 18
# 4                  10                  9                  1
# ...               ...                ...                ...
# 4904                5                  3                  2
# 4905                9                  5                  4
# 4906                7                  4                  3
# 4907                1                  1                  0
# 4908                8                  4                  4
#
# [4909 rows x 3 columns]

# %%
df1.join(df2_indexed, on='id', how='inner', lsuffix='_left', rsuffix='_right') # теперь работает
# Out:
#              id  Всего сообщений_left  Сообщений ученика_left  \
# 0     162881860                    14                       9
# 1     163720554                    19                      10
# 2     542225346                     8                       2
# 3     433941477                    15                       8
# 4     178097868                    56                      33
# ...         ...                   ...                     ...
# 4550   52048252                     9                       5
# 4551   44351820                     7                       4
# 4552   32888911                     1                       1
# 4553   29237466                     8                       4
# 4554    6629705                     3                       2
#
#       Сообщений учителя_left  Всего сообщений_right  Сообщений ученика_right  \
# 0                          5                     15                       10
# 1                          9                     38                       20
# 2                          6                     12                        5
# 3                          7                     41                       22
# 4                         23                     77                       46
# ...                      ...                    ...                      ...
# 4550                       4                      9                        5
# 4551                       3                      7                        4
# 4552                       0                      1                        1
# 4553                       4                      8                        4
# 4554                       1                      4                        3
#
#       Сообщений учителя_right
# 0                           5
# 1                          18
# 2                           7
# 3                          19
# 4                          31
# ...                       ...
# 4550                        4
# 4551                        3
# 4552                        0
# 4553                        4
# 4554                        1
#
# [4560 rows x 7 columns]

# %%
# или так

df1_indexed = df1.set_index('id')
df1_indexed.join(df2_indexed, how='inner', lsuffix='_left', rsuffix='_right')
# Out:
#            Всего сообщений_left  Сообщений ученика_left  \
# id
# 1526163                       8                       6
# 1658327                      14                       9
# 3424983                       4                       4
# 3602010                       9                       5
# 5125376                       4                       2
# ...                         ...                     ...
# 544735677                    16                       8
# 544763802                     6                       4
# 544776546                    12                       7
# 544794584                     7                       3
# 544952797                    12                       7
#
#            Сообщений учителя_left  Всего сообщений_right  \
# id
# 1526163                         2                      9
# 1658327                         5                     15
# 3424983                         0                      5
# 3602010                         4                      9
# 5125376                         2                      5
# ...                           ...                    ...
# 544735677                       8                     17
# 544763802                       2                      7
# 544776546                       5                     16
# 544794584                       4                      8
# 544952797                       5                     13
#
#            Сообщений ученика_right  Сообщений учителя_right
# id
# 1526163                          7                        2
# 1658327                         10                        5
# 3424983                          5                        0
# 3602010                          5                        4
# 5125376                          3                        2
# ...                            ...                      ...
# 544735677                        9                        8
# 544763802                        5                        2
# 544776546                        9                        7
# 544794584                        4                        4
# 544952797                        8                        5
#
# [4560 rows x 6 columns]

# %% [markdown]
# ## concat
# еще есть append, но его удалят

# %%
pd.concat([df1, df2], axis=0) # вдоль строк, то есть приклеить снизу
# Out:
#              id  Всего сообщений  Сообщений ученика  Сообщений учителя
# 0     162881860               14                  9                  5
# 1     163720554               19                 10                  9
# 2     542225346                8                  2                  6
# 3     433941477               15                  8                  7
# 4     178097868               56                 33                 23
# ...         ...              ...                ...                ...
# 4904   53318580                5                  3                  2
# 4905   52048252                9                  5                  4
# 4906   44351820                7                  4                  3
# 4907   32888911                1                  1                  0
# 4908   29237466                8                  4                  4
#
# [9464 rows x 4 columns]

# %%
pd.concat([df1, df2], axis=1) # вдоль столбцов, то есть приклеить справа
# Out:
#                id  Всего сообщений  Сообщений ученика  Сообщений учителя  \
# 0     162881860.0             14.0                9.0                5.0
# 1     163720554.0             19.0               10.0                9.0
# 2     542225346.0              8.0                2.0                6.0
# 3     433941477.0             15.0                8.0                7.0
# 4     178097868.0             56.0               33.0               23.0
# ...           ...              ...                ...                ...
# 4904          NaN              NaN                NaN                NaN
# 4905          NaN              NaN                NaN                NaN
# 4906          NaN              NaN                NaN                NaN
# 4907          NaN              NaN                NaN                NaN
# 4908          NaN              NaN                NaN                NaN
#
#              id  Всего сообщений  Сообщений ученика  Сообщений учителя
# 0     304741397               14                  6                  8
# 1     222306609               30                 16                 14
# 2     406929921                9                  5                  4
# 3     439552406               34                 16                 18
# 4     173017583               10                  9                  1
# ...         ...              ...                ...                ...
# 4904   53318580                5                  3                  2
# 4905   52048252                9                  5                  4
# 4906   44351820                7                  4                  3
# 4907   32888911                1                  1                  0
# 4908   29237466                8                  4                  4
#
# [4909 rows x 8 columns]

# %%
df1 = df1.drop_duplicates()
df2 = df2.drop_duplicates()

# %%
def extract_day(x):
    return x[:x.find('_')]

# %%
extract_day("20_17-05_20-00_.tsv")
# Out:
# '20'

# %%
df1['Day'] = extract_day("20_17-05_20-00_.tsv")
df2['Day'] = 2
# Out:
# C:\Users\igumn\AppData\Local\Temp\ipykernel_9132\741989584.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Day'] = 1
# C:\Users\igumn\AppData\Local\Temp\ipykernel_9132\741989584.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Day'] = 2

# %%
df1.head()
# Out:
#           id  Всего сообщений  Сообщений ученика  Сообщений учителя  Day
# 0  162881860               14                  9                  5    1
# 1  163720554               19                 10                  9    1
# 2  542225346                8                  2                  6    1
# 3  433941477               15                  8                  7    1
# 4  178097868               56                 33                 23    1

# %%
df2.head()
# Out:
#           id  Всего сообщений  Сообщений ученика  Сообщений учителя  Day
# 0  304741397               14                  6                  8    2
# 1  222306609               30                 16                 14    2
# 2  406929921                9                  5                  4    2
# 3  439552406               34                 16                 18    2
# 4  173017583               10                  9                  1    2

# %%
pd.concat([df1, df2], axis=0)
# Out:
#              id  Всего сообщений  Сообщений ученика  Сообщений учителя  Day
# 0     162881860               14                  9                  5    1
# 1     163720554               19                 10                  9    1
# 2     542225346                8                  2                  6    1
# 3     433941477               15                  8                  7    1
# 4     178097868               56                 33                 23    1
# ...         ...              ...                ...                ...  ...
# 4904   53318580                5                  3                  2    2
# 4905   52048252                9                  5                  4    2
# 4906   44351820                7                  4                  3    2
# 4907   32888911                1                  1                  0    2
# 4908   29237466                8                  4                  4    2
#
# [9435 rows x 5 columns]

# %%
files = glob("data/*tsv") # получим список с файлами
files
# Out:
# ['data\\10_16-05_20-57_.tsv',
#  'data\\20_17-05_20-00_.tsv',
#  'data\\30_18-05_08-11_.tsv',
#  'data\\40_19-05_04-00_.tsv']

# %%
tables = []
for file in files:
    print(file)
    df = pd.read_csv(file, sep='\t').drop_duplicates()
    day = file[5:file.find("_")]
    # print(day)
    df['Day'] = day
    tables.append(df)
# Out:
# data\10_16-05_20-57_.tsv
# data\20_17-05_20-00_.tsv
# data\30_18-05_08-11_.tsv
# data\40_19-05_04-00_.tsv

# %%
len(tables)
# Out:
# 4

# %%
df = pd.concat(tables, axis=0)
df.Day.value_counts()
# Out:
# 40    5120
# 30    4946
# 20    4896
# 10    4539
# Name: Day, dtype: int64

# %%
pd.concat(
    [pd.read_csv(file, sep='\t').drop_duplicates().assign(Day=file[5:file.find("_")]) for file in files],
    axis=0
)
# Out:
#              id  Всего сообщений  Сообщений ученика  Сообщений учителя Day
# 0     162881860               14                  9                  5  10
# 1     163720554               19                 10                  9  10
# 2     542225346                8                  2                  6  10
# 3     433941477               15                  8                  7  10
# 4     178097868               56                 33                 23  10
# ...         ...              ...                ...                ...  ..
# 5116   60990566                5                  3                  2  40
# 5117   53318580                5                  3                  2  40
# 5118   52048252                9                  5                  4  40
# 5119   44351820                7                  4                  3  40
# 5120   32888911                1                  1                  0  40
#
# [19501 rows x 5 columns]

# %% [markdown]
# ## практика

# %%
# посмотрим на файлы в папке
files = glob("data/*csv")
files
# Out:
# ['data\\Cars_Country.csv', 'data\\Cars_Multi.csv', 'data\\Cars_Price.csv']

# %%
# прочитаем данные в датафреймы
country = pd.read_csv('data\\Cars_Country.csv')
country
# Out:
#    origin country
# 0       1     USA
# 1       2  Europe
# 2       3   Japan

# %%
# прочитаем данные в датафреймы
multi = pd.read_csv('data\\Cars_Multi.csv')
multi.head()
# Out:
#    ID   mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0   1  18.0          8         307.0        130    3504          12.0     70
# 1   2  15.0          8         350.0        165    3693          11.5     70
# 2   3  18.0          8         318.0        150    3436          11.0     70
# 3   4  16.0          8         304.0        150    3433          12.0     70
# 4   5  17.0          8         302.0        140    3449          10.5     70
#
#    origin                   car_name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
price = pd.read_csv('data\\Cars_Price.csv')
price.head()
# Out:
#    ID        price
# 0   1  25561.59078
# 1   2  24221.42273
# 2   3  27240.84373
# 3   4  33684.96888
# 4   5  20000.00000

# %%
# соедините три датафрейма в один 
# за один шаг -- никак. сначала надо соединить два, потом еще два.
tmp_df = pd.merge(multi, price, on='ID', how='left', validate='one_to_one')
tmp_df.head()
# Out:
#    ID   mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0   1  18.0          8         307.0        130    3504          12.0     70
# 1   2  15.0          8         350.0        165    3693          11.5     70
# 2   3  18.0          8         318.0        150    3436          11.0     70
# 3   4  16.0          8         304.0        150    3433          12.0     70
# 4   5  17.0          8         302.0        140    3449          10.5     70
#
#    origin                   car_name        price
# 0       1  chevrolet chevelle malibu  25561.59078
# 1       1          buick skylark 320  24221.42273
# 2       1         plymouth satellite  27240.84373
# 3       1              amc rebel sst  33684.96888
# 4       1                ford torino  20000.00000

# %%
pd.merge(left=tmp_df, right=country, on='origin')
# Out:
#       ID   mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0      1  18.0          8         307.0        130    3504          12.0
# 1      2  15.0          8         350.0        165    3693          11.5
# 2      3  18.0          8         318.0        150    3436          11.0
# 3      4  16.0          8         304.0        150    3433          12.0
# 4      5  17.0          8         302.0        140    3449          10.5
# ..   ...   ...        ...           ...        ...     ...           ...
# 393  355  34.5          4         100.0          ?    2320          15.8
# 394  360  28.1          4         141.0         80    3230          20.4
# 395  361  30.7          6         145.0         76    3160          19.6
# 396  376  36.0          4         105.0         74    1980          15.3
# 397  395  44.0          4          97.0         52    2130          24.6
#
#      model  origin                   car_name        price country
# 0       70       1  chevrolet chevelle malibu  25561.59078     USA
# 1       70       1          buick skylark 320  24221.42273     USA
# 2       70       1         plymouth satellite  27240.84373     USA
# 3       70       1              amc rebel sst  33684.96888     USA
# 4       70       1                ford torino  20000.00000     USA
# ..     ...     ...                        ...          ...     ...
# 393     81       2                renault 18i  30000.00000  Europe
# 394     81       2  peugeot 505s turbo diesel  20000.00000  Europe
# 395     81       2               volvo diesel  40000.00000  Europe
# 396     82       2        volkswagen rabbit l  33472.79144  Europe
# 397     82       2                  vw pickup  37000.00000  Europe
#
# [398 rows x 12 columns]

# %% [markdown]
# # Pivoting

# %% [markdown]
# Широкие и длинные данные:
#
# ![изображение.png](attachment:4cfd1b5a-279e-417f-a1bf-81e061afca40.png)

# %% [markdown]
# ## WIDE to LONG

# %% [markdown]
# ![изображение.png](attachment:9dc04f48-f5f6-4764-a410-6f3500a60967.png)

# %%
example = pd.DataFrame({'first': ['John', 'Mary'],
                       'last': ['Doe', 'Bo'],
                       'height': [5.5, 6.0],
                       'weight': [130, 150]})
example
# Out:
#   first last  height  weight
# 0  John  Doe     5.5     130
# 1  Mary   Bo     6.0     150

# %% [markdown]
# ### stack

# %%
st = example.stack() # получаем multiIndex объект
st
# Out:
# 0  first     John
#    last       Doe
#    height     5.5
#    weight     130
# 1  first     Mary
#    last        Bo
#    height     6.0
#    weight     150
# dtype: object

# %%
st.index
# Out:
# MultiIndex([(0,  'first'),
#             (0,   'last'),
#             (0, 'height'),
#             (0, 'weight'),
#             (1,  'first'),
#             (1,   'last'),
#             (1, 'height'),
#             (1, 'weight')],
#            )

# %%
st[(0, 'first')] # неприятно, непонятно
# Out:
# 'John'

# %%
st.unstack() # обратно
# Out:
#   first last height weight
# 0  John  Doe    5.5    130
# 1  Mary   Bo    6.0    150

# %% [markdown]
# ### melt

# %%
# понятный вариант
example.melt(id_vars=['first', 'last'], 
             value_vars=['height', 'weight'])
# Out:
#   first last variable  value
# 0  John  Doe   height    5.5
# 1  Mary   Bo   height    6.0
# 2  John  Doe   weight  130.0
# 3  Mary   Bo   weight  150.0

# %% [markdown]
# ### wide_to_long

# %% [markdown]
# ![изображение.png](attachment:6004e029-c36c-4211-9dcf-020f98bc5855.png)

# %% [markdown]
# ## LONG to WIDE

# %% [markdown]
# ![изображение.png](attachment:a9b0652e-8830-461e-930b-399e40141f02.png)

# %% [markdown]
#     pivot() provides general purpose pivoting with various data types (strings, numerics, etc.)
#     pivot() just reshapes or substitute value in each cell
#     pivot() has only three arguments
#
#         index - what goes on index,
#         column - what goes on column name,
#         values - what goes on cell value
#
#     pivot() can't aggregate data

# %%
df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two', 'two'],
                   'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'baz': [1, 2, 3, 4, 5, 6],
                   'zoo': ['x', 'y', 'z', 'q', 'w', 't']})
df.head()
# Out:
#    foo bar  baz zoo
# 0  one   A    1   x
# 1  one   B    2   y
# 2  one   C    3   z
# 3  two   A    4   q
# 4  two   B    5   w

# %%
df.pivot(index='foo', columns='bar', values='baz')
# Out:
# bar  A  B  C
# foo
# one  1  2  3
# two  4  5  6

# %%
df.pivot(index='foo', columns='bar', values=['baz', 'zoo']) # опять multiindex...
# Out:
#     baz       zoo
# bar   A  B  C   A  B  C
# foo
# one   1  2  3   x  y  z
# two   4  5  6   q  w  t

# %%
tmp_pivot = df.pivot(index='foo', columns='bar', values=['baz', 'zoo'])
tmp_pivot.columns
# Out:
# MultiIndex([('baz', 'A'),
#             ('baz', 'B'),
#             ('baz', 'C'),
#             ('zoo', 'A'),
#             ('zoo', 'B'),
#             ('zoo', 'C')],
#            names=[None, 'bar'])

# %%
tmp_pivot.columns = list(range(1, 7))
tmp_pivot
# Out:
#      1  2  3  4  5  6
# foo
# one  1  2  3  x  y  z
# two  4  5  6  q  w  t

# %%
tmp_pivot = df.pivot(index='foo', columns='bar', values=['baz', 'zoo'])
tmp_pivot.T.reset_index().T
# Out:
#            0    1    2    3    4    5
# foo
# level_0  baz  baz  baz  zoo  zoo  zoo
# bar        A    B    C    A    B    C
# one        1    2    3    x    y    z
# two        4    5    6    q    w    t

# %% [markdown]
# ### pivot_table
#
#     pivot_table() can do aggregation of numeric data.
#     pivot_table() can be used to create spreadsheet-style pivot tables.
#     pivot_table() has arguments like aggfunc, fill_value, dropna ...

# %%
df = pd.DataFrame({"A": ["foo", "foo", "foo", "foo", "foo", "bar", "bar", "bar", "bar"],
                   "B": ["one", "one", "one", "two", "two", "one", "one", "two", "two"],
                   "C": ["small", "large", "large", "small", "small", "large", "small", "small", "large"],
                   "D": [1, 2, 2, 3, 3, 4, 5, 6, 7],
                   "E": [2, 4, 5, 5, 6, 6, 8, 9, 9]})
df
# Out:
#      A    B      C  D  E
# 0  foo  one  small  1  2
# 1  foo  one  large  2  4
# 2  foo  one  large  2  5
# 3  foo  two  small  3  5
# 4  foo  two  small  3  6
# 5  bar  one  large  4  6
# 6  bar  one  small  5  8
# 7  bar  two  small  6  9
# 8  bar  two  large  7  9

# %%
df.pivot(index='A', columns='B', values='D')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [128], line 1
# ----> 1 df.pivot(index='A', columns='B', values='D')
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:8567, in DataFrame.pivot(self, index, columns, values)
#    8561 @Substitution("")
#    8562 @Appender(_shared_docs["pivot"])
#    8563 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self"])
#    8564 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    8565     from pandas.core.reshape.pivot import pivot
# -> 8567     return pivot(self, index=index, columns=columns, values=values)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\pivot.py:540, in pivot(data, index, columns, values)
#     536         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     537 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     538 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     539 # "Hashable"
# --> 540 return indexed.unstack(columns_listlike)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\series.py:4455, in Series.unstack(self, level, fill_value)
#    4412 """
#    4413 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4414
#    (...)
#    4451 b    2    4
#    4452 """
#    4453 from pandas.core.reshape.reshape import unstack
# -> 4455 return unstack(self, level, fill_value)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\reshape.py:489, in unstack(obj, level, fill_value)
#     487 if is_1d_only_ea_dtype(obj.dtype):
#     488     return _unstack_extension_series(obj, level, fill_value)
# --> 489 unstacker = _Unstacker(
#     490     obj.index, level=level, constructor=obj._constructor_expanddim
#     491 )
#     492 return unstacker.get_result(
#     493     obj._values, value_columns=None, fill_value=fill_value
#     494 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\reshape.py:137, in _Unstacker.__init__(self, index, level, constructor)
#     129 if num_cells > np.iinfo(np.int32).max:
#     130     warnings.warn(
#     131         f"The following operation may generate {num_cells} cells "
#     132         f"in the resulting pandas object.",
#     133         PerformanceWarning,
#     134         stacklevel=find_stack_level(),
#     135     )
# --> 137 self._make_selectors()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\reshape.py:189, in _Unstacker._make_selectors(self)
#     186 mask.put(selector, True)
#     188 if mask.sum() < len(self.index):
# --> 189     raise ValueError("Index contains duplicate entries, cannot reshape")
#     191 self.group_index = comp_index
#     192 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
df.pivot_table(index='A', columns='B', values='D')
# Out:
# B         one  two
# A
# bar  4.500000  6.5
# foo  1.666667  3.0

# %%
df.pivot_table(index='A', columns='B', values='D', aggfunc=np.sum)
# Out:
# B    one  two
# A
# bar    9   13
# foo    5    6

# %%
pd.pivot_table(df, values=['D', 'E'], index=['A', 'B'], columns=['C'], aggfunc=len)
# Out:
#      A    B     D           E
# C           large small large small
# 0  bar  one   1.0   1.0   1.0   1.0
# 1  bar  two   1.0   1.0   1.0   1.0
# 2  foo  one   2.0   1.0   2.0   1.0
# 3  foo  two   NaN   2.0   NaN   2.0

# %%
pd.pivot_table(df, values=['D', 'E'], index=['A', 'B'], columns=['C'], aggfunc=len).reset_index()

# %% [markdown]
# ## практика

# %%
import seaborn as sns
import matplotlib.pyplot as plt

flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
# получите следующую таблицу (широкий вид)
matrix = flights.pivot (index = 'year', columns = 'month',  values = 'passengers')
matrix
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 6))
sns.heatmap(matrix, annot=True, fmt='d', cmap='Greens', ax=ax);

# %%
matrix.reset_index().melt(id_vars='year').rename(columns={'value':'passengers'})
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1950   Jan         115
# 2    1951   Jan         145
# 3    1952   Jan         171
# 4    1953   Jan         196
# ..    ...   ...         ...
# 139  1956   Dec         306
# 140  1957   Dec         336
# 141  1958   Dec         337
# 142  1959   Dec         405
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [markdown]
# ![изображение.png](attachment:f173a588-cf4a-4e10-a6b3-3cfb8ee0444d.png)

# %%
# ?pd.melt
# Out:
# Signature:
# pd.melt(
#     frame: 'DataFrame',
#     id_vars=None,
#     value_vars=None,
#     var_name=None,
#     value_name='value',
#     col_level=None,
#     ignore_index: 'bool' = True,
# ) -> 'DataFrame'
# Docstring:
# Unpivot a DataFrame from wide to long format, optionally leaving identifiers set.
#
# This function is useful to massage a DataFrame into a format where one
# or more columns are identifier variables (`id_vars`), while all other
# columns, considered measured variables (`value_vars`), are "unpivoted" to
# the row axis, leaving just two non-identifier columns, 'variable' and
# 'value'.
#
# Parameters
# ----------
# id_vars : tuple, list, or ndarray, optional
#     Column(s) to use as identifier variables.
# value_vars : tuple, list, or ndarray, optional
#     Column(s) to unpivot. If not specified, uses all columns that
#     are not set as `id_vars`.
# var_name : scalar
#     Name to use for the 'variable' column. If None it uses
#     ``frame.columns.name`` or 'variable'.
# value_name : scalar, default 'value'
#     Name to use for the 'value' column.
# col_level : int or str, optional
#     If columns are a MultiIndex then use this level to melt.
# ignore_index : bool, default True
#     If True, original index is ignored. If False, the original index is retained.
#     Index labels will be repeated as necessary.
#
#     .. versionadded:: 1.1.0
#
# Returns
# -------
# DataFrame
#     Unpivoted DataFrame.
#
# See Also
# --------
# DataFrame.melt : Identical method.
# pivot_table : Create a spreadsheet-style pivot table as a DataFrame.
# DataFrame.pivot : Return reshaped DataFrame organized
#     by given index / column values.
# DataFrame.explode : Explode a DataFrame from list-like
#         columns to long format.
#
# Notes
# -----
# Reference :ref:`the user guide <reshaping.melt>` for more examples.
#
# Examples
# --------
# >>> df = pd.DataFrame({'A': {0: 'a', 1: 'b', 2: 'c'},
# ...                    'B': {0: 1, 1: 3, 2: 5},
# ...                    'C': {0: 2, 1: 4, 2: 6}})
# >>> df
#    A  B  C
# 0  a  1  2
# 1  b  3  4
# 2  c  5  6
#
# >>> pd.melt(df, id_vars=['A'], value_vars=['B'])
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5
#
# >>> pd.melt(df, id_vars=['A'], value_vars=['B', 'C'])
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5
# 3  a        C      2
# 4  b        C      4
# 5  c        C      6
#
# The names of 'variable' and 'value' columns can be customized:
#
# >>> pd.melt(df, id_vars=['A'], value_vars=['B'],
# ...         var_name='myVarname', value_name='myValname')
#    A myVarname  myValname
# 0  a         B          1
# 1  b         B          3
# 2  c         B          5
#
# Original index values can be kept around:
#
# >>> pd.melt(df, id_vars=['A'], value_vars=['B', 'C'], ignore_index=False)
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5
# 0  a        C      2
# 1  b        C      4
# 2  c        C      6
#
# If you have multi-index columns:
#
# >>> df.columns = [list('ABC'), list('DEF')]
# >>> df
#    A  B  C
#    D  E  F
# 0  a  1  2
# 1  b  3  4
# 2  c  5  6
#
# >>> pd.melt(df, col_level=0, id_vars=['A'], value_vars=['B'])
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5
#
# >>> pd.melt(df, id_vars=[('A', 'D')], value_vars=[('B', 'E')])
#   (A, D) variable_0 variable_1  value
# 0      a          B          E      1
# 1      b          B          E      3
# 2      c          B          E      5
# File:      c:\users\igumn\appdata\roaming\python\python39\site-packages\pandas\core\reshape\melt.py
# Type:      function

# %%
# ваш код

# %%
# арггрегируйте полученную таблицу обратно в длинный вид при помощи melt

# %% [markdown]
# ## практика еще раз

# %%
pop = pd.read_csv('https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-population.csv')

# %%
pop.head()
# Out:
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0

# %%
# получите таблицу следующего вида

# %% [markdown]
# ![изображение.png](attachment:fa5f1d0a-28ba-40f1-a51e-6bd7340818b2.png)

# %%
#######

# %%
area = pd.read_csv('https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-areas.csv')
abbrev = pd.read_csv('https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-abbrevs.csv')

# %%
area.head()
# Out:
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707

# %%
abbrev.head()
# Out:
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
# соедините информацию в один датафрейма

# %%
pd.merge(area, abbrev, on = 'state').shape
# Out:
# (51, 3)

# %%
pd.merge(area, abbrev, on = 'state').head()
# Out:
#         state  area (sq. mi) abbreviation
# 0     Alabama          52423           AL
# 1      Alaska         656425           AK
# 2     Arizona         114006           AZ
# 3    Arkansas          53182           AR
# 4  California         163707           CA

# %%
area = area.set_index('state')
abbrev = abbrev.set_index('state')

# %%
area = area.join(abbrev)

# %%
area.shape
# Out:
# (52, 2)

# %%
area.head()
# Out:
#             area (sq. mi) abbreviation
# state
# Alabama             52423           AL
# Alaska             656425           AK
# Arizona            114006           AZ
# Arkansas            53182           AR
# California         163707           CA

# %%
area[area.isna().astype(int).sum(axis=1) != 0]
# Out:
#              area (sq. mi) abbreviation
# state
# Puerto Rico           3515          NaN

# %%
# постройте распределение area (hist)

# %%
# создайте новый столбец с первой буквой кода штата

# %%
# посчитайте число вхождений каждой категории в столбце, созданном в предыдущем пункте

# %%
# постройте распределение для каждой категории на одном графике
